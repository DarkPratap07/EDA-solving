# %% [markdown]
# Solve the following questions:-
#
# 1]What is the age distribution of customers?
#
# 2]What percentage of customers are male vs. female?
#
# 3]Which city has the highest number of customers?
#
# 4]How does annual income vary across different cities?
#
# 5]Is there a relationship between Annual Income and Spending Score?
#
# 6]What is the average spending score of customers who made a purchase vs. those who didn’t?
#
# 7]Which age group spends the most?
#
# 8]Do males and females differ in average annual income or spending score?

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("customer_data.csv")
df.head()
# Out:
#    CustomerID  Age  Gender  Annual_Income_k$  Spending_Score    City  \
# 0           1   56  Female                65              29   Delhi
# 1           2   46    Male               136              37    Pune
# 2           3   32  Female                25              38  Mumbai
# 3           4   60    Male               118              83  Mumbai
# 4           5   25    Male               143               8    Pune
#
#    Purchased
# 0          0
# 1          0
# 2          1
# 3          1
# 4          0

# %%
df.shape
# Out:
# (200, 8)

# %%
df.describe()
# Out:
#        CustomerID         Age  Annual_Income_k$  Spending_Score   Purchased
# count  200.000000  200.000000        200.000000      200.000000  200.000000
# mean   100.500000   41.570000         86.875000       50.225000    0.645000
# std     57.879185   13.715527         38.532495       28.639404    0.479714
# min      1.000000   18.000000         20.000000        1.000000    0.000000
# 25%     50.750000   30.000000         52.750000       26.750000    0.000000
# 50%    100.500000   42.000000         87.000000       50.500000    1.000000
# 75%    150.250000   54.000000        119.000000       74.250000    1.000000
# max    200.000000   64.000000        149.000000       99.000000    1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   CustomerID        200 non-null    int64
#  1   Age               200 non-null    int64
#  2   Gender            200 non-null    object
#  3   Annual_Income_k$  200 non-null    int64
#  4   Spending_Score    200 non-null    int64
#  5   City              200 non-null    object
#  6   Purchased         200 non-null    int64
# dtypes: int64(5), object(2)
# memory usage: 11.1+ KB

# %%
df.isna().sum()
# Out:
# CustomerID          0
# Age                 0
# Gender              0
# Annual_Income_k$    0
# Spending_Score      0
# City                0
# Purchased           0
# dtype: int64

# %%
df.dtypes
# Out:
# CustomerID           int64
# Age                  int64
# Gender              object
# Annual_Income_k$     int64
# Spending_Score       int64
# City                object
# Purchased            int64
# dtype: object

# %%
df.hist()
plt.tight_layout()
plt.show()

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [CustomerID, Age, Gender, Annual_Income_k$, Spending_Score, City, Purchased]
# Index: []

# %%
df.boxplot()
plt.show()

# %%
sn.histplot(x="Age",data=df)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
c=df["Age"].value_counts()
plt.bar(c.index,c.values)
# Out:
# <BarContainer object of 46 artists>

# %%
z=df["Gender"].value_counts()
z
# Out:
# Gender
# Female    108
# Male       92
# Name: count, dtype: int64

# %%
for gender,i in z.items():
    print(f"{gender}:{i/len(df)*100}")
# Out:
# Female:54.0
# Male:46.0

# %%
df["City"].value_counts().plot(kind="bar")
plt.title("No of customer per city")
plt.ylabel("No of customers")
plt.show()

# %%
sn.boxplot(x="City",y="Annual_Income_k$",data=df)
# Out:
# <Axes: xlabel='City', ylabel='Annual_Income_k$'>

# %%
sn.scatterplot(x="Annual_Income_k$",y="Spending_Score",data=df)
# Out:
# <Axes: xlabel='Annual_Income_k$', ylabel='Spending_Score'>

# %%
df[["Annual_Income_k$", "Spending_Score"]].corr()
# Out:
#                   Annual_Income_k$  Spending_Score
# Annual_Income_k$          1.000000        0.015294
# Spending_Score            0.015294        1.000000

# %%
sn.boxplot(x="Purchased",y="Spending_Score",data=df)
plt.legend()

# %%
sn.barplot(x="Purchased", y="Spending_Score", data=df, ci=95, palette="pastel")
# Out:
# <Axes: xlabel='Purchased', ylabel='Spending_Score'>

# %%
df['Spending_Score'].max()
# Out:
# 99

# %%
# Use pandas qcut to automatically create 5 equal-sized age groups
df['Age_Group'] = pd.qcut(df['Age'], 5)

# Calculate average spending score for each group
age_spending = df.groupby('Age_Group')['Spending_Score'].mean()
print(age_spending)

# Optional: Bar plot
age_spending.plot(kind='bar', color='skyblue', edgecolor='black')
plt.title("Average Spending Score by Age Group")
plt.xlabel("Age Group")
plt.ylabel("Average Spending Score")
plt.show()
# Out:
# Age_Group
# (17.999, 26.0]    46.902439
# (26.0, 38.6]      47.743590
# (38.6, 46.0]      47.813953
# (46.0, 56.0]      55.000000
# (56.0, 64.0]      54.138889
# Name: Spending_Score, dtype: float64

# %%
z=df.groupby("Gender")[["Annual_Income_k$","Spending_Score"]].mean()
print(z)
z.plot(kind="bar",color=['skyblue', 'lightgreen'],edgecolor="black")
# Out:
#         Annual_Income_k$  Spending_Score
# Gender
# Female         88.277778       50.546296
# Male           85.228261       49.847826
# <Axes: xlabel='Gender'>
